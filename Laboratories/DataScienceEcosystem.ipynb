# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:7d1ff5f8-a6ca-4297-86b6-3c27fb8a464a.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:45ab5ee4-ca1e-4e5b-8cbb-06d375ac087d.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# - Scala
# - Python
# - Java
# ![4-dslanguages.png](attachment:f025a3f4-2e10-4824-95e2-dad006fe31c6.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# - Pandas
# - Plotly
# - Numpy
# - Keras
# - SciPy
# ![5-dslibraries.png](attachment:ed2c40c1-424a-4b9d-8f78-3125b020bc60.png)

# %% [markdown]
# **Data Science Tools**
#
# | Tool Name |
# |---|
# | Jupyter Notebook |
# | RStudio |
# | Spyder |
# ![6-dstools.png](attachment:78659944-9e92-4c6a-a26c-29513c44b80c.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# ![7-introarithmetic.png](attachment:ea5d7788-51ca-4b54-bf71-6054051e29c7.png)

# %%
x = 3 + 2
y = 8 / 2
z = 49 * 7
person_age = 26
voting_age = 18
q = person_age>= voting_age
print(x, y, z, q)
# Out:
# 5 4.0 343 True

# %%
(3*4)+5
# This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:2e71181e-cd03-4508-9cd8-512c22929cf6.png)

# %%
minute_to_hour = 200/60
print(minute_to_hour)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png.png](attachment:aa8d51bd-6272-4699-9eec-a7836c631211.png)

# %% [markdown]
# # Objectives:
#
# * List popular languages for Data Science.
# * Demonstrate basic arithmetic operations in Python.
# * Convert minutes to hours using Python expressions.
# * Apply Python to real-world data manipulation tasks.
# * (Add any additional objectives covered in the notebook)

# %% [markdown]
# ![10-objectives.png](attachment:0d392605-e5a9-44ff-a94f-5d2c164b0ae5.png)
